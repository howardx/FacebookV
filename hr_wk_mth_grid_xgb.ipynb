# %%
import pandas as pd
import numpy as np

from itertools import tee, izip
import os, sys
import scipy

import xgboost as xgb

from sklearn import cross_validation, metrics # Additional scklearn functions
from sklearn.grid_search import GridSearchCV # Perforing grid search

# %%
train = pd.read_csv('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/train_hr_wk_mth.csv')
test = pd.read_csv('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/test_hr_wk_mth.csv')

print train.head()
print test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-da8207275020> in <module>()
# ----> 1 train = pd.read_csv('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/train_hr_wk_mth.csv')
#       2 test = pd.read_csv('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/test_hr_wk_mth.csv')
#       3
#       4 print train.head()
#       5 print test.head()
#
# NameError: name 'pd' is not defined

# %%
# a helper function takes an iterable, return its stepwise pair tuple in a list
# [1, 2, 3, 4, 5] -> [(1, 2), (2, 3), (3, 4), (4, 5)]
def pairwise(iterable):
    floor, ceiling = tee(iterable)
    next(ceiling, None)
    return izip(floor, ceiling)

# a helper function takes a df, a column name, a list of floor/ceiling values 
# "split" the df based on the given column, using the list of floor/ceiling values, return list of df
#
# flr_clg will be floor EXclusive, ceiling INclusive - need special treatment for the first split
def split_df_rows_on_col_ranges(df, col, flr_clg):
    splitted_df = []
    first = True
    for fc in flr_clg:
        if first:
            splitted_df.append(df[ (df[col] >= fc[0]) & (df[col] <= fc[1]) ])
            first = False
        else:
            splitted_df.append(df[ (df[col] > fc[0]) & (df[col] <= fc[1]) ])
    return splitted_df

# a helper function takes x bars, cut y bars inside and return a dictionary of grids
def cut_y_bars_in_x_bar(x_bars, y, y_bin_tuple):
    gridDict = {}
    xidx = 0
    for xbar in x_bars:        
        # getting list of N bars (grids here already) based on y values, all within 1 xbar
        y_bars_in_xbar = split_df_rows_on_col_ranges(xbar, y, y_bin_tuple)
            
        yidx = 0
        for grid in y_bars_in_xbar:
            gridDict[(xidx, yidx)] = grid # gather output with x,y index
            yidx = yidx + 1     
        xidx = xidx + 1
    return gridDict

'''
input parameters for def get_grids():
- train_file - input filename with path for the training set

- test_file - input filename with path for the test set

- outputFile - boolean that tells whether you want NxM files as output or a dict of pd.DataFrame
               as output, format would be (x_idx, y_idx) : df_for_grid. If you want file as output
               then x_idx, y_idx will appear in output files' name

- train_output - only used if the 3rd parameter is set to True, will be the path to store NxM files for training set,
                 each file contains a grid of data points

- test_output - only used if the 3rd parameter is set to True, will be the path to store NxM files for testing set,
                each file contains a grid of data points

- n - NxM grid, the N value, for x axis

- m - NxM grid, the M value, for y axis

- x - column name of the x coordinate in input file

- y - column name of the y coordinate in input file

'''
def get_grids(train_file, test_file, outputFile = False, train_output = None, test_output = None, n = 10, m = 10, x = 'x', y = 'y'):
    train = pd.read_csv(train_file)
    test = pd.read_csv(test_file)
    
    # getting the cutoff values for x and y axis, using training set ONLY - because of the IMPORTANT ASSUMPTION -
    # TESTING SET IS SUBSET OF TRAINING SET IN TERMS OF X AND Y COORDINATES
    x_count, x_cutoff = np.histogram(train[x], bins = n)
    y_count, y_cutoff = np.histogram(train[y], bins = m)

    # transform cutoff values into step-wise tuples
    x_bin_tuple = [(floor, ceiling) for floor, ceiling in pairwise(x_cutoff)]
    y_bin_tuple = [(floor, ceiling) for floor, ceiling in pairwise(y_cutoff)]

    train_x_splits = split_df_rows_on_col_ranges(train, x, x_bin_tuple) # getting list of N bars based on x values for train
    test_x_splits = split_df_rows_on_col_ranges(test, x, x_bin_tuple) # getting list of N bars based on x values for test

    # within each bar (overall N) splitted based on x, there will be M splits based on y - each one is a grid
    trainDict = cut_y_bars_in_x_bar(train_x_splits, y, y_bin_tuple)
    testDict = cut_y_bars_in_x_bar(test_x_splits, y, y_bin_tuple)

    if outputFile:
        for key in trainDict:
            filename = 'train_' + 'x' + str(key[0]) + '_y' + str(key[1]) + '.csv'
            fullpath = os.path.join(train_output, filename)
            trainDict[key].to_csv(fullpath, index = False)
        for key in testDict:
            filename = 'test_' + 'x' + str(key[0]) + '_y' + str(key[1]) + '.csv'
            fullpath = os.path.join(test_output, filename)
            testDict[key].to_csv(fullpath, index = False)
    return (trainDict, testDict)

# %% [markdown]
# # Generate grids and store in dictionary (and files)

# %%
#train_g, test_g = get_grids('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/train_hr_wk_mth.csv',
#                '/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/test_hr_wk_mth.csv',
#                outputFile = True, 
#                train_output = '/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/50_50_grid/train',
#                test_output = '/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/50_50_grid/test',
#                n = 50, m = 50, x = 'x', y = 'y')

# %%
train_g, test_g = get_grids('/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/train_hr_wk_mth.csv',
                '/home/ec2-user/Kaggle/facebook_Jul_2016/feature_engineered_input/hr_wk_mth/test_hr_wk_mth.csv',
                n = 50, m = 50)

# %% [markdown]
# # Train/Validation/Test split

# %%
print test_g[(6,8)].shape # number of testing set data points in grid 1, 8)
print len(test_g) # number of grids form testing set
print test_g[(6,8)].head()

print train_g[(6,8)].shape
print len(train_g)
print train_g[(6,8)].head()
# Out:
# (2753, 8)
# 2500
#        row_id       x       y  accuracy    time  hour  weekday  month
# 4394     4394  1.3877  1.7159        29  817057    10        1      7
# 5557     5557  1.3798  1.7341        12  947451    23        7     10
# 16597   16597  1.2697  1.7303        51  957863     5        1     11
# 19386   19386  1.2186  1.6120        83  815774    13        7      7
# 20132   20132  1.3330  1.6060       289  941808     1        4     10
# (9343, 9)
# 2500
#        row_id       x       y  accuracy    time    place_id  hour  weekday  \
# 11683   11683  1.2002  1.6124        36  398887  6855596818     1        5
# 13290   13290  1.2360  1.6957        20  632924  6472715293    13        6
# 19390   19390  1.3616  1.7906        58  114062  8610202964     6        3
# 20089   20089  1.2124  1.7503        14  148596  2495375117     5        6
# 20203   20203  1.2912  1.6980       162  627651  3707683630    21        2
#
#        month
# 11683     10
# 13290      3
# 19390      3
# 20089      4
# 20203      3

# %%
train_68_pd = train_g[(6,8)][['x','y','accuracy','time', 'hour', 'weekday', 'month', 'place_id']]
train_68 = train_68_pd.as_matrix()

test_68_pd = test_g[(6,8)][['x','y','accuracy','time', 'hour', 'weekday', 'month']]
test_68 = test_68_pd.as_matrix()

print train_68_pd.shape

print train_68[0:3, :]
print type(train_68)

train_sz = train_68.shape
print train_sz

print test_68[0:3, :]
# Out:
# (9343, 8)
# [[  1.20020000e+00   1.61240000e+00   3.60000000e+01   3.98887000e+05
#     1.00000000e+00   5.00000000e+00   1.00000000e+01   6.85559682e+09]
#  [  1.23600000e+00   1.69570000e+00   2.00000000e+01   6.32924000e+05
#     1.30000000e+01   6.00000000e+00   3.00000000e+00   6.47271529e+09]
#  [  1.36160000e+00   1.79060000e+00   5.80000000e+01   1.14062000e+05
#     6.00000000e+00   3.00000000e+00   3.00000000e+00   8.61020296e+09]]
# <type 'numpy.ndarray'>
# (9343, 8)
# [[  1.38770000e+00   1.71590000e+00   2.90000000e+01   8.17057000e+05
#     1.00000000e+01   1.00000000e+00   7.00000000e+00]
#  [  1.37980000e+00   1.73410000e+00   1.20000000e+01   9.47451000e+05
#     2.30000000e+01   7.00000000e+00   1.00000000e+01]
#  [  1.26970000e+00   1.73030000e+00   5.10000000e+01   9.57863000e+05
#     5.00000000e+00   1.00000000e+00   1.10000000e+01]]

# %% [markdown]
# # Factorize Place_id into xgboost compatible format (0, 1, 2...)

# %%
place_id = train_68[:,7] # original class labels before factorization
data = scipy.delete(train_68, 7, 1)  # delete the original class label column - cannot be used by xgboost

print place_id[0:3]
print data.shape
# Out:
# [  6.85559682e+09   6.47271529e+09   8.61020296e+09]
# (9343, 7)

# %%
factorized_placeID, unique_placeID = pd.factorize(place_id)
overall_num_of_classes = len(unique_placeID) # needed by xgboost multiclass objective

print overall_num_of_classes
# Out:
# 660

# %%
# reshape so dimension matches for appending to original dataset
class_np_horizontal = np.reshape(factorized_placeID, (train_sz[0], 1)) 
print class_np_horizontal.shape

# add factorized labels as the last column of original matrix
data = np.hstack((data, class_np_horizontal))
print data.shape
# Out:
# (9343, 1)
# (9343, 8)

# %% [markdown]
# # Convert Train/Test/Validation sets to xgboost compatible data structure dMatrix

# %%
num_train = int(train_sz[0] * 0.8)
num_validation = int(train_sz[0] * 0.2)
# num_test will be all the testing set

train_68_set = data[0:num_train, :]
validate_68_set = data[num_train:, :]

print train_68_set.shape
print validate_68_set.shape
print test_68.shape
# Out:
# (7474, 8)
# (1869, 8)
# (2753, 7)

# %%
train_X = train_68_set[:,0:6]
train_Y = train_68_set[:, 7]
print train_X.shape

validate_X = validate_68_set[:,0:6]
validate_Y = validate_68_set[:, 7]
print validate_Y.shape

test_X = test_68
# Out:
# (7474, 6)
# (1869,)

# %% [markdown]
# # Set xgboost model parameters

# %%
# convert data to xgboost compatible structure - DMatrix
xg_train = xgb.DMatrix( train_X, label = train_Y)
xg_validation = xgb.DMatrix(validate_X, label = validate_Y)
xg_test = xgb.DMatrix(test_X)

# %%
# setup parameters for xgboost with a python dictionary
param = {}

# use softmax multi-class classification
param['objective'] = 'multi:softprob' # tells boosted trees to output probability

# param[booster] - default is set to "gbtree" - gradient boosted tree

# scale weight of positive examples
param['eta'] = 0.05 # Parameters for Tree Booster - Booster parameter

param['max_depth'] = 6 # Parameters for Tree Booster - Booster parameter

param['silent'] = 1 # whether to print logs
param['nthread'] = 36 # parallelism

param['eval_metric'] = 'merror'

param['num_class'] = overall_num_of_classes # number of classes

# %%
# specify traing/testing set for model training 
watchlist = [ (xg_train,'train'), (xg_validation, 'validation') ]

# specify the number of weak classifiers (base boosters) in the ensemble #
num_round = overall_num_of_classes

# %% [markdown]
# # Train xgboost model - takes a while

# %%
# train the model
bst_return_prob = xgb.train(param, xg_train, num_round, watchlist)
# Out:
# [0]	train-merror:0.625903	validation-merror:0.651150
# [1]	train-merror:0.575863	validation-merror:0.596041
# [2]	train-merror:0.539336	validation-merror:0.573569
# [3]	train-merror:0.515654	validation-merror:0.552167
# [4]	train-merror:0.495050	validation-merror:0.531835
# [5]	train-merror:0.479529	validation-merror:0.522739
# [6]	train-merror:0.470029	validation-merror:0.516854
# [7]	train-merror:0.459995	validation-merror:0.513644
# [8]	train-merror:0.451565	validation-merror:0.507758
# [9]	train-merror:0.445545	validation-merror:0.502943
# [10]	train-merror:0.439791	validation-merror:0.500268
# [11]	train-merror:0.434841	validation-merror:0.497057
# [12]	train-merror:0.429489	validation-merror:0.496522
# [13]	train-merror:0.423200	validation-merror:0.496522
# [14]	train-merror:0.417982	validation-merror:0.493312
# [15]	train-merror:0.412764	validation-merror:0.490637
# [16]	train-merror:0.409419	validation-merror:0.488497
# [17]	train-merror:0.404469	validation-merror:0.486891
# [18]	train-merror:0.401258	validation-merror:0.483681
# [19]	train-merror:0.396976	validation-merror:0.481541
# [20]	train-merror:0.393364	validation-merror:0.477261
# [21]	train-merror:0.389484	validation-merror:0.476726
# [22]	train-merror:0.385068	validation-merror:0.475655
# [23]	train-merror:0.380252	validation-merror:0.475655
# [24]	train-merror:0.375702	validation-merror:0.471910
# [25]	train-merror:0.371153	validation-merror:0.471910
# [26]	train-merror:0.367808	validation-merror:0.470840
# [27]	train-merror:0.361921	validation-merror:0.469235
# [28]	train-merror:0.358175	validation-merror:0.468700
# [29]	train-merror:0.354161	validation-merror:0.467630
# [30]	train-merror:0.348542	validation-merror:0.467630
# [31]	train-merror:0.344260	validation-merror:0.467630
# [32]	train-merror:0.339443	validation-merror:0.467095
# [33]	train-merror:0.335831	validation-merror:0.464419
# [34]	train-merror:0.331817	validation-merror:0.463884
# [35]	train-merror:0.328338	validation-merror:0.463884
# [36]	train-merror:0.323789	validation-merror:0.462279
# [37]	train-merror:0.319909	validation-merror:0.462279
# [38]	train-merror:0.316430	validation-merror:0.462279
# [39]	train-merror:0.312550	validation-merror:0.461209
# [40]	train-merror:0.308001	validation-merror:0.459604
# [41]	train-merror:0.304121	validation-merror:0.460139
# [42]	train-merror:0.300642	validation-merror:0.459069
# [43]	train-merror:0.298368	validation-merror:0.459604
# [44]	train-merror:0.295424	validation-merror:0.459604
# [45]	train-merror:0.290607	validation-merror:0.457999
# [46]	train-merror:0.287798	validation-merror:0.456929
# [47]	train-merror:0.284051	validation-merror:0.457999
# [48]	train-merror:0.281777	validation-merror:0.456929
# [49]	train-merror:0.278566	validation-merror:0.455859
# [50]	train-merror:0.274686	validation-merror:0.455859
# [51]	train-merror:0.271608	validation-merror:0.456929
# [52]	train-merror:0.267594	validation-merror:0.457464
# [53]	train-merror:0.264651	validation-merror:0.457999
# [54]	train-merror:0.260369	validation-merror:0.458534
# [55]	train-merror:0.256891	validation-merror:0.459069
# [56]	train-merror:0.253679	validation-merror:0.459604
# [57]	train-merror:0.250870	validation-merror:0.460139
# [58]	train-merror:0.246856	validation-merror:0.456929
# [59]	train-merror:0.244849	validation-merror:0.458534
# [60]	train-merror:0.241638	validation-merror:0.459604
# [61]	train-merror:0.237758	validation-merror:0.456929
# [62]	train-merror:0.235349	validation-merror:0.456394
# [63]	train-merror:0.232539	validation-merror:0.455859
# [64]	train-merror:0.229864	validation-merror:0.456394
# [65]	train-merror:0.226786	validation-merror:0.455859
# [66]	train-merror:0.225314	validation-merror:0.455324
# [67]	train-merror:0.223040	validation-merror:0.456394
# [68]	train-merror:0.219695	validation-merror:0.458534
# [69]	train-merror:0.216484	validation-merror:0.458534
# [70]	train-merror:0.213540	validation-merror:0.458534
# [71]	train-merror:0.211533	validation-merror:0.458534
# [72]	train-merror:0.209393	validation-merror:0.460139
# [73]	train-merror:0.206717	validation-merror:0.459604
# [74]	train-merror:0.204308	validation-merror:0.459069
# [75]	train-merror:0.200294	validation-merror:0.461209
# [76]	train-merror:0.197618	validation-merror:0.460139
# [77]	train-merror:0.196414	validation-merror:0.459069
# [78]	train-merror:0.193604	validation-merror:0.457999
# [79]	train-merror:0.190661	validation-merror:0.455859
# [80]	train-merror:0.187717	validation-merror:0.457999
# [81]	train-merror:0.185175	validation-merror:0.458534
# [82]	train-merror:0.181964	validation-merror:0.459604
# [83]	train-merror:0.179422	validation-merror:0.460674
# [84]	train-merror:0.177816	validation-merror:0.459069
# [85]	train-merror:0.176211	validation-merror:0.459069
# [86]	train-merror:0.174338	validation-merror:0.459069
# [87]	train-merror:0.171394	validation-merror:0.458534
# [88]	train-merror:0.169387	validation-merror:0.459604
# [89]	train-merror:0.166845	validation-merror:0.460674
# [90]	train-merror:0.164838	validation-merror:0.459604
# [91]	train-merror:0.163902	validation-merror:0.460674
# [92]	train-merror:0.161493	validation-merror:0.460674
# [93]	train-merror:0.159486	validation-merror:0.460139
# [94]	train-merror:0.157747	validation-merror:0.459604
# [95]	train-merror:0.156007	validation-merror:0.459604
# [96]	train-merror:0.154268	validation-merror:0.458534
# [97]	train-merror:0.152663	validation-merror:0.460139
# [98]	train-merror:0.151325	validation-merror:0.459604
# [99]	train-merror:0.148916	validation-merror:0.457999
# [100]	train-merror:0.147444	validation-merror:0.457464
# [101]	train-merror:0.146106	validation-merror:0.455859
# [102]	train-merror:0.144635	validation-merror:0.455324
# [103]	train-merror:0.142762	validation-merror:0.455324
# [104]	train-merror:0.141825	validation-merror:0.454789
# [105]	train-merror:0.140487	validation-merror:0.454254
# [106]	train-merror:0.139149	validation-merror:0.455324
# [107]	train-merror:0.137677	validation-merror:0.455859
# [108]	train-merror:0.136741	validation-merror:0.455324
# [109]	train-merror:0.134734	validation-merror:0.454789
# [110]	train-merror:0.133128	validation-merror:0.455859
# [111]	train-merror:0.130720	validation-merror:0.456929
# [112]	train-merror:0.129783	validation-merror:0.457999
# [113]	train-merror:0.127910	validation-merror:0.458534
# [114]	train-merror:0.126572	validation-merror:0.458534
# [115]	train-merror:0.124833	validation-merror:0.458534
# [116]	train-merror:0.123093	validation-merror:0.457999
# [117]	train-merror:0.120685	validation-merror:0.457999
# [118]	train-merror:0.119481	validation-merror:0.458534
# [119]	train-merror:0.117474	validation-merror:0.459604
# [120]	train-merror:0.115601	validation-merror:0.458534
# [121]	train-merror:0.114397	validation-merror:0.459069
# [122]	train-merror:0.112523	validation-merror:0.459069
# [123]	train-merror:0.110918	validation-merror:0.458534
# [124]	train-merror:0.109580	validation-merror:0.457999
# [125]	train-merror:0.108376	validation-merror:0.459604
# [126]	train-merror:0.107707	validation-merror:0.459604
# [127]	train-merror:0.106235	validation-merror:0.458534
# [128]	train-merror:0.105700	validation-merror:0.458534
# [129]	train-merror:0.104094	validation-merror:0.459604
# [130]	train-merror:0.102890	validation-merror:0.459604
# [131]	train-merror:0.100883	validation-merror:0.460139
# [132]	train-merror:0.099946	validation-merror:0.460674
# [133]	train-merror:0.099411	validation-merror:0.460139
# [134]	train-merror:0.098475	validation-merror:0.460139
# [135]	train-merror:0.097806	validation-merror:0.459604
# [136]	train-merror:0.096334	validation-merror:0.459069
# [137]	train-merror:0.095130	validation-merror:0.459604
# [138]	train-merror:0.094059	validation-merror:0.459604
# [139]	train-merror:0.092721	validation-merror:0.459604
# [140]	train-merror:0.091517	validation-merror:0.459604
# [141]	train-merror:0.090447	validation-merror:0.460139
# [142]	train-merror:0.088841	validation-merror:0.459069
# [143]	train-merror:0.088039	validation-merror:0.459604
# [144]	train-merror:0.087102	validation-merror:0.458534
# [145]	train-merror:0.086032	validation-merror:0.458534
# [146]	train-merror:0.085229	validation-merror:0.459069
# [147]	train-merror:0.084560	validation-merror:0.459069
# [148]	train-merror:0.083891	validation-merror:0.459069
# [149]	train-merror:0.082954	validation-merror:0.459069
# [150]	train-merror:0.082018	validation-merror:0.458534
# [151]	train-merror:0.081081	validation-merror:0.459604
# [152]	train-merror:0.079208	validation-merror:0.459604
# [153]	train-merror:0.078539	validation-merror:0.459604
# [154]	train-merror:0.077469	validation-merror:0.460139
# [155]	train-merror:0.076264	validation-merror:0.460139
# [156]	train-merror:0.075595	validation-merror:0.459069
# [157]	train-merror:0.074926	validation-merror:0.457999
# [158]	train-merror:0.074124	validation-merror:0.457999
# [159]	train-merror:0.073722	validation-merror:0.458534
# [160]	train-merror:0.072652	validation-merror:0.457999
# [161]	train-merror:0.071849	validation-merror:0.457999
# [162]	train-merror:0.071046	validation-merror:0.459069
# [163]	train-merror:0.070377	validation-merror:0.459069
# [164]	train-merror:0.069842	validation-merror:0.460139
# [165]	train-merror:0.068237	validation-merror:0.460674
# [166]	train-merror:0.068103	validation-merror:0.460139
# [167]	train-merror:0.067434	validation-merror:0.460674
# [168]	train-merror:0.066363	validation-merror:0.461744
# [169]	train-merror:0.065962	validation-merror:0.460139
# [170]	train-merror:0.065159	validation-merror:0.459069
# [171]	train-merror:0.064490	validation-merror:0.459069
# [172]	train-merror:0.064089	validation-merror:0.459604
# [173]	train-merror:0.063687	validation-merror:0.458534
# [174]	train-merror:0.063152	validation-merror:0.458534
# [175]	train-merror:0.062751	validation-merror:0.457464
# [176]	train-merror:0.062617	validation-merror:0.459069
# [177]	train-merror:0.062483	validation-merror:0.460139
# [178]	train-merror:0.061814	validation-merror:0.461744
# [179]	train-merror:0.061145	validation-merror:0.461744
# [180]	train-merror:0.060610	validation-merror:0.461744
# [181]	train-merror:0.060209	validation-merror:0.461744
# [182]	train-merror:0.059941	validation-merror:0.460674
# [183]	train-merror:0.059807	validation-merror:0.459069
# [184]	train-merror:0.059807	validation-merror:0.459604
# [185]	train-merror:0.059406	validation-merror:0.459604
# [186]	train-merror:0.059138	validation-merror:0.459604
# [187]	train-merror:0.058871	validation-merror:0.459604
# [188]	train-merror:0.058336	validation-merror:0.459069
# [189]	train-merror:0.057800	validation-merror:0.459604
# [190]	train-merror:0.057667	validation-merror:0.459604
# [191]	train-merror:0.057399	validation-merror:0.460139
# [192]	train-merror:0.056998	validation-merror:0.459069
# [193]	train-merror:0.056329	validation-merror:0.458534
# [194]	train-merror:0.056195	validation-merror:0.457999
# [195]	train-merror:0.055927	validation-merror:0.457999
# [196]	train-merror:0.055660	validation-merror:0.457999
# [197]	train-merror:0.055392	validation-merror:0.457999
# [198]	train-merror:0.054857	validation-merror:0.456929
# [199]	train-merror:0.054455	validation-merror:0.457464
# [200]	train-merror:0.054188	validation-merror:0.459069
# [201]	train-merror:0.053786	validation-merror:0.457464
# [202]	train-merror:0.053786	validation-merror:0.456929
# [203]	train-merror:0.053251	validation-merror:0.457999
# [204]	train-merror:0.052984	validation-merror:0.459069
# [205]	train-merror:0.052448	validation-merror:0.459069
# [206]	train-merror:0.052315	validation-merror:0.459604
# [207]	train-merror:0.052315	validation-merror:0.460139
# [208]	train-merror:0.051913	validation-merror:0.460139
# [209]	train-merror:0.051646	validation-merror:0.460139
# [210]	train-merror:0.050977	validation-merror:0.460674
# [211]	train-merror:0.050575	validation-merror:0.460139
# [212]	train-merror:0.050442	validation-merror:0.460139
# [213]	train-merror:0.050308	validation-merror:0.459604
# [214]	train-merror:0.049773	validation-merror:0.457999
# [215]	train-merror:0.049639	validation-merror:0.457999
# [216]	train-merror:0.049237	validation-merror:0.457464
# [217]	train-merror:0.048970	validation-merror:0.458534
# [218]	train-merror:0.048435	validation-merror:0.457999
# [219]	train-merror:0.048033	validation-merror:0.458534
# [220]	train-merror:0.048033	validation-merror:0.459604
# [221]	train-merror:0.047498	validation-merror:0.459604
# [222]	train-merror:0.047364	validation-merror:0.459604
# [223]	train-merror:0.046695	validation-merror:0.459069
# [224]	train-merror:0.046294	validation-merror:0.459069
# [225]	train-merror:0.045892	validation-merror:0.460139
# [226]	train-merror:0.045892	validation-merror:0.460139
# [227]	train-merror:0.045892	validation-merror:0.459069
# [228]	train-merror:0.045759	validation-merror:0.459604
# [229]	train-merror:0.045759	validation-merror:0.460139
# [230]	train-merror:0.045491	validation-merror:0.459604
# [231]	train-merror:0.045223	validation-merror:0.459604
# [232]	train-merror:0.045090	validation-merror:0.458534
# [233]	train-merror:0.044554	validation-merror:0.459069
# [234]	train-merror:0.044153	validation-merror:0.458534
# [235]	train-merror:0.044153	validation-merror:0.457999
# [236]	train-merror:0.044019	validation-merror:0.458534
# [237]	train-merror:0.043885	validation-merror:0.458534
# [238]	train-merror:0.043618	validation-merror:0.457464
# [239]	train-merror:0.043350	validation-merror:0.456394
# [240]	train-merror:0.043350	validation-merror:0.456929
# [241]	train-merror:0.043350	validation-merror:0.457464
# [242]	train-merror:0.043350	validation-merror:0.456929
# [243]	train-merror:0.043083	validation-merror:0.457464
# [244]	train-merror:0.043083	validation-merror:0.457999
# [245]	train-merror:0.042949	validation-merror:0.456929
# [246]	train-merror:0.042815	validation-merror:0.455324
# [247]	train-merror:0.042681	validation-merror:0.456929
# [248]	train-merror:0.042414	validation-merror:0.456929
# [249]	train-merror:0.042146	validation-merror:0.456929
# [250]	train-merror:0.042012	validation-merror:0.456929
# [251]	train-merror:0.042012	validation-merror:0.457999
# [252]	train-merror:0.041745	validation-merror:0.457999
# [253]	train-merror:0.041611	validation-merror:0.457999
# [254]	train-merror:0.041477	validation-merror:0.457464
# [255]	train-merror:0.041343	validation-merror:0.457999
# [256]	train-merror:0.041343	validation-merror:0.457999
# [257]	train-merror:0.041343	validation-merror:0.458534
# [258]	train-merror:0.041210	validation-merror:0.458534
# [259]	train-merror:0.041076	validation-merror:0.459069
# [260]	train-merror:0.041076	validation-merror:0.458534
# [261]	train-merror:0.040942	validation-merror:0.459069
# [262]	train-merror:0.040674	validation-merror:0.459069
# [263]	train-merror:0.040674	validation-merror:0.459069
# [264]	train-merror:0.040273	validation-merror:0.457999
# [265]	train-merror:0.040139	validation-merror:0.457999
# [266]	train-merror:0.040139	validation-merror:0.458534
# [267]	train-merror:0.040005	validation-merror:0.458534
# [268]	train-merror:0.039872	validation-merror:0.459604
# [269]	train-merror:0.039872	validation-merror:0.458534
# [270]	train-merror:0.039604	validation-merror:0.459069
# [271]	train-merror:0.039470	validation-merror:0.459069
# [272]	train-merror:0.039336	validation-merror:0.459069
# [273]	train-merror:0.039069	validation-merror:0.460139
# [274]	train-merror:0.038935	validation-merror:0.459604
# [275]	train-merror:0.039069	validation-merror:0.459604
# [276]	train-merror:0.038935	validation-merror:0.459604
# [277]	train-merror:0.039069	validation-merror:0.459604
# [278]	train-merror:0.038935	validation-merror:0.459604
# [279]	train-merror:0.038801	validation-merror:0.459604
# [280]	train-merror:0.038667	validation-merror:0.460139
# [281]	train-merror:0.038534	validation-merror:0.460139
# [282]	train-merror:0.038266	validation-merror:0.459604
# [283]	train-merror:0.038266	validation-merror:0.460139
# [284]	train-merror:0.038132	validation-merror:0.461209
# [285]	train-merror:0.037731	validation-merror:0.459604
# [286]	train-merror:0.037463	validation-merror:0.460674
# [287]	train-merror:0.037329	validation-merror:0.460674
# [288]	train-merror:0.037329	validation-merror:0.461744
# [289]	train-merror:0.037196	validation-merror:0.461744
# [290]	train-merror:0.036928	validation-merror:0.461744
# [291]	train-merror:0.036928	validation-merror:0.462279
# [292]	train-merror:0.036660	validation-merror:0.461209
# [293]	train-merror:0.036527	validation-merror:0.461744
# [294]	train-merror:0.036259	validation-merror:0.461209
# [295]	train-merror:0.035991	validation-merror:0.462279
# [296]	train-merror:0.035991	validation-merror:0.461744
# [297]	train-merror:0.035991	validation-merror:0.461209
# [298]	train-merror:0.035724	validation-merror:0.462814
# [299]	train-merror:0.035456	validation-merror:0.461209
# [300]	train-merror:0.035456	validation-merror:0.461209
# [301]	train-merror:0.035456	validation-merror:0.461744
# [302]	train-merror:0.035322	validation-merror:0.461744
# [303]	train-merror:0.035189	validation-merror:0.461209
# [304]	train-merror:0.035055	validation-merror:0.461209
# [305]	train-merror:0.034921	validation-merror:0.460674
# [306]	train-merror:0.034787	validation-merror:0.460674
# [307]	train-merror:0.034787	validation-merror:0.460674
# [308]	train-merror:0.034520	validation-merror:0.461209
# [309]	train-merror:0.034386	validation-merror:0.461209
# [310]	train-merror:0.033984	validation-merror:0.461209
# [311]	train-merror:0.033717	validation-merror:0.461209
# [312]	train-merror:0.033717	validation-merror:0.461744
# [313]	train-merror:0.033583	validation-merror:0.461744
# [314]	train-merror:0.033449	validation-merror:0.461209
# [315]	train-merror:0.033449	validation-merror:0.462814
# [316]	train-merror:0.033449	validation-merror:0.461209
# [317]	train-merror:0.033449	validation-merror:0.460674
# [318]	train-merror:0.033315	validation-merror:0.460139
# [319]	train-merror:0.033449	validation-merror:0.460674
# [320]	train-merror:0.033182	validation-merror:0.462279
# [321]	train-merror:0.033315	validation-merror:0.461209
# [322]	train-merror:0.032914	validation-merror:0.461744
# [323]	train-merror:0.032780	validation-merror:0.461744
# [324]	train-merror:0.032647	validation-merror:0.462279
# [325]	train-merror:0.032647	validation-merror:0.462814
# [326]	train-merror:0.032379	validation-merror:0.461744
# [327]	train-merror:0.032379	validation-merror:0.461744
# [328]	train-merror:0.032245	validation-merror:0.461209
# [329]	train-merror:0.032111	validation-merror:0.461209
# [330]	train-merror:0.031844	validation-merror:0.461744
# [331]	train-merror:0.031576	validation-merror:0.460674
# [332]	train-merror:0.031576	validation-merror:0.460674
# [333]	train-merror:0.031576	validation-merror:0.461209
# [334]	train-merror:0.031710	validation-merror:0.460674
# [335]	train-merror:0.031309	validation-merror:0.460139
# [336]	train-merror:0.031041	validation-merror:0.459069
# [337]	train-merror:0.031175	validation-merror:0.459604
# [338]	train-merror:0.030773	validation-merror:0.459604
# [339]	train-merror:0.030773	validation-merror:0.460139
# [340]	train-merror:0.030640	validation-merror:0.459069
# [341]	train-merror:0.030506	validation-merror:0.459069
# [342]	train-merror:0.030506	validation-merror:0.459069
# [343]	train-merror:0.030372	validation-merror:0.459069
# [344]	train-merror:0.030238	validation-merror:0.459069
# [345]	train-merror:0.030238	validation-merror:0.460139
# [346]	train-merror:0.029971	validation-merror:0.461209
# [347]	train-merror:0.029837	validation-merror:0.459604
# [348]	train-merror:0.029837	validation-merror:0.459604
# [349]	train-merror:0.029703	validation-merror:0.461209
# [350]	train-merror:0.029703	validation-merror:0.459604
# [351]	train-merror:0.029569	validation-merror:0.460139
# [352]	train-merror:0.029435	validation-merror:0.460139
# [353]	train-merror:0.029302	validation-merror:0.460139
# [354]	train-merror:0.029034	validation-merror:0.460139
# [355]	train-merror:0.028900	validation-merror:0.460139
# [356]	train-merror:0.028766	validation-merror:0.460674
# [357]	train-merror:0.028766	validation-merror:0.460674
# [358]	train-merror:0.028766	validation-merror:0.460674
# [359]	train-merror:0.028766	validation-merror:0.460674
# [360]	train-merror:0.028633	validation-merror:0.460139
# [361]	train-merror:0.028365	validation-merror:0.459069
# [362]	train-merror:0.028231	validation-merror:0.459069
# [363]	train-merror:0.028231	validation-merror:0.459604
# [364]	train-merror:0.028231	validation-merror:0.459604
# [365]	train-merror:0.028231	validation-merror:0.459069
# [366]	train-merror:0.028097	validation-merror:0.459604
# [367]	train-merror:0.028097	validation-merror:0.459604
# [368]	train-merror:0.028097	validation-merror:0.460139
# [369]	train-merror:0.028097	validation-merror:0.459069
# [370]	train-merror:0.028097	validation-merror:0.459604
# [371]	train-merror:0.027830	validation-merror:0.459069
# [372]	train-merror:0.027696	validation-merror:0.459604
# [373]	train-merror:0.027428	validation-merror:0.458534
# [374]	train-merror:0.027295	validation-merror:0.459604
# [375]	train-merror:0.027161	validation-merror:0.461209
# [376]	train-merror:0.027161	validation-merror:0.459604
# [377]	train-merror:0.027295	validation-merror:0.460139
# [378]	train-merror:0.027161	validation-merror:0.460139
# [379]	train-merror:0.027161	validation-merror:0.461209
# [380]	train-merror:0.027161	validation-merror:0.461209
# [381]	train-merror:0.027161	validation-merror:0.461209
# [382]	train-merror:0.027027	validation-merror:0.461744
# [383]	train-merror:0.027027	validation-merror:0.461744
# [384]	train-merror:0.026893	validation-merror:0.461209
# [385]	train-merror:0.026759	validation-merror:0.461209
# [386]	train-merror:0.026759	validation-merror:0.461744
# [387]	train-merror:0.026492	validation-merror:0.461744
# [388]	train-merror:0.026358	validation-merror:0.461209
# [389]	train-merror:0.026224	validation-merror:0.461744
# [390]	train-merror:0.026224	validation-merror:0.461209
# [391]	train-merror:0.026090	validation-merror:0.460674
# [392]	train-merror:0.026090	validation-merror:0.460674
# [393]	train-merror:0.025957	validation-merror:0.460674
# [394]	train-merror:0.025823	validation-merror:0.460139
# [395]	train-merror:0.025823	validation-merror:0.460139
# [396]	train-merror:0.025823	validation-merror:0.460139
# [397]	train-merror:0.025689	validation-merror:0.460674
# [398]	train-merror:0.025555	validation-merror:0.460674
# [399]	train-merror:0.025288	validation-merror:0.460139
# [400]	train-merror:0.025154	validation-merror:0.460139
# [401]	train-merror:0.025020	validation-merror:0.460139
# [402]	train-merror:0.024886	validation-merror:0.460139
# [403]	train-merror:0.024886	validation-merror:0.461209
# [404]	train-merror:0.024752	validation-merror:0.460674
# [405]	train-merror:0.024619	validation-merror:0.460674
# [406]	train-merror:0.024485	validation-merror:0.460674
# [407]	train-merror:0.024217	validation-merror:0.461209
# [408]	train-merror:0.024083	validation-merror:0.460139
# [409]	train-merror:0.023950	validation-merror:0.460674
# [410]	train-merror:0.023950	validation-merror:0.460139
# [411]	train-merror:0.023950	validation-merror:0.460139
# [412]	train-merror:0.023816	validation-merror:0.460674
# [413]	train-merror:0.023950	validation-merror:0.460674
# [414]	train-merror:0.023816	validation-merror:0.460674
# [415]	train-merror:0.023682	validation-merror:0.460139
# [416]	train-merror:0.023548	validation-merror:0.460674
# [417]	train-merror:0.023415	validation-merror:0.460674
# [418]	train-merror:0.023415	validation-merror:0.461744
# [419]	train-merror:0.023281	validation-merror:0.461209
# [420]	train-merror:0.023281	validation-merror:0.460674
# [421]	train-merror:0.023013	validation-merror:0.461209
# [422]	train-merror:0.022879	validation-merror:0.459604
# [423]	train-merror:0.022879	validation-merror:0.459604
# [424]	train-merror:0.022879	validation-merror:0.461209
# [425]	train-merror:0.022879	validation-merror:0.461744
# [426]	train-merror:0.022879	validation-merror:0.461744
# [427]	train-merror:0.022612	validation-merror:0.460674
# [428]	train-merror:0.022746	validation-merror:0.460139
# [429]	train-merror:0.022478	validation-merror:0.461744
# [430]	train-merror:0.022344	validation-merror:0.461209
# [431]	train-merror:0.022344	validation-merror:0.461744
# [432]	train-merror:0.022210	validation-merror:0.461209
# [433]	train-merror:0.022210	validation-merror:0.460674
# [434]	train-merror:0.022077	validation-merror:0.460674
# [435]	train-merror:0.022077	validation-merror:0.460674
# [436]	train-merror:0.022077	validation-merror:0.459604
# [437]	train-merror:0.022077	validation-merror:0.460139
# [438]	train-merror:0.021943	validation-merror:0.460674
# [439]	train-merror:0.021943	validation-merror:0.460674
# [440]	train-merror:0.021943	validation-merror:0.460139
# [441]	train-merror:0.021809	validation-merror:0.460139
# [442]	train-merror:0.021675	validation-merror:0.461209
# [443]	train-merror:0.021541	validation-merror:0.460674
# [444]	train-merror:0.021140	validation-merror:0.461744
# [445]	train-merror:0.020872	validation-merror:0.462279
# [446]	train-merror:0.020872	validation-merror:0.463349
# [447]	train-merror:0.021006	validation-merror:0.463349
# [448]	train-merror:0.020872	validation-merror:0.463349
# [449]	train-merror:0.020872	validation-merror:0.463349
# [450]	train-merror:0.020739	validation-merror:0.463884
# [451]	train-merror:0.020739	validation-merror:0.463349
# [452]	train-merror:0.020739	validation-merror:0.463349
# [453]	train-merror:0.020605	validation-merror:0.462814
# [454]	train-merror:0.020605	validation-merror:0.462814
# [455]	train-merror:0.020605	validation-merror:0.463349
# [456]	train-merror:0.020605	validation-merror:0.463349
# [457]	train-merror:0.020605	validation-merror:0.464419
# [458]	train-merror:0.020605	validation-merror:0.464419
# [459]	train-merror:0.020605	validation-merror:0.464419
# [460]	train-merror:0.020605	validation-merror:0.463884
# [461]	train-merror:0.020471	validation-merror:0.463884
# [462]	train-merror:0.020471	validation-merror:0.463884
# [463]	train-merror:0.020337	validation-merror:0.464955
# [464]	train-merror:0.020337	validation-merror:0.464419
# [465]	train-merror:0.020203	validation-merror:0.463884
# [466]	train-merror:0.020203	validation-merror:0.464419
# [467]	train-merror:0.019936	validation-merror:0.463349
# [468]	train-merror:0.019936	validation-merror:0.463349
# [469]	train-merror:0.019936	validation-merror:0.463349
# [470]	train-merror:0.019936	validation-merror:0.462814
# [471]	train-merror:0.019936	validation-merror:0.463349
# [472]	train-merror:0.019936	validation-merror:0.462814
# [473]	train-merror:0.019668	validation-merror:0.462279
# [474]	train-merror:0.019668	validation-merror:0.462279
# [475]	train-merror:0.019668	validation-merror:0.462814
# [476]	train-merror:0.019534	validation-merror:0.462279
# [477]	train-merror:0.019534	validation-merror:0.462279
# [478]	train-merror:0.019133	validation-merror:0.461744
# [479]	train-merror:0.019267	validation-merror:0.461744
# [480]	train-merror:0.019133	validation-merror:0.461744
# [481]	train-merror:0.019133	validation-merror:0.462279
# [482]	train-merror:0.018999	validation-merror:0.462279
# [483]	train-merror:0.019133	validation-merror:0.461209
# [484]	train-merror:0.018999	validation-merror:0.461744
# [485]	train-merror:0.018865	validation-merror:0.461744
# [486]	train-merror:0.018865	validation-merror:0.461744
# [487]	train-merror:0.018732	validation-merror:0.462279
# [488]	train-merror:0.018732	validation-merror:0.461744
# [489]	train-merror:0.018464	validation-merror:0.461744
# [490]	train-merror:0.018464	validation-merror:0.461744
# [491]	train-merror:0.018196	validation-merror:0.461744
# [492]	train-merror:0.018063	validation-merror:0.461744
# [493]	train-merror:0.017929	validation-merror:0.461209
# [494]	train-merror:0.017661	validation-merror:0.461209
# [495]	train-merror:0.017661	validation-merror:0.462279
# [496]	train-merror:0.017661	validation-merror:0.462279
# [497]	train-merror:0.017527	validation-merror:0.462814
# [498]	train-merror:0.017394	validation-merror:0.461744
# [499]	train-merror:0.017394	validation-merror:0.461744
# [500]	train-merror:0.017394	validation-merror:0.462279
# [501]	train-merror:0.017394	validation-merror:0.461744
# [502]	train-merror:0.017260	validation-merror:0.461744
# [503]	train-merror:0.017126	validation-merror:0.461744
# [504]	train-merror:0.016858	validation-merror:0.461744
# [505]	train-merror:0.016858	validation-merror:0.461744
# [506]	train-merror:0.016725	validation-merror:0.461744
# [507]	train-merror:0.016725	validation-merror:0.462279
# [508]	train-merror:0.016725	validation-merror:0.462279
# [509]	train-merror:0.016591	validation-merror:0.462279
# [510]	train-merror:0.016591	validation-merror:0.461744
# [511]	train-merror:0.016457	validation-merror:0.461744
# [512]	train-merror:0.016323	validation-merror:0.461744
# [513]	train-merror:0.016189	validation-merror:0.461209
# [514]	train-merror:0.016056	validation-merror:0.461744
# [515]	train-merror:0.016056	validation-merror:0.462279
# [516]	train-merror:0.016056	validation-merror:0.462814
# [517]	train-merror:0.015922	validation-merror:0.461744
# [518]	train-merror:0.015922	validation-merror:0.462279
# [519]	train-merror:0.015922	validation-merror:0.462279
# [520]	train-merror:0.015922	validation-merror:0.462279
# [521]	train-merror:0.015788	validation-merror:0.461744
# [522]	train-merror:0.015654	validation-merror:0.462279
# [523]	train-merror:0.015654	validation-merror:0.462814
# [524]	train-merror:0.015788	validation-merror:0.462814
# [525]	train-merror:0.015788	validation-merror:0.463349
# [526]	train-merror:0.015654	validation-merror:0.463349
# [527]	train-merror:0.015520	validation-merror:0.463349
# [528]	train-merror:0.015520	validation-merror:0.462814
# [529]	train-merror:0.015520	validation-merror:0.462814
# [530]	train-merror:0.015654	validation-merror:0.462279
# [531]	train-merror:0.015520	validation-merror:0.461209
# [532]	train-merror:0.015520	validation-merror:0.461744
# [533]	train-merror:0.015520	validation-merror:0.462279
# [534]	train-merror:0.015387	validation-merror:0.461744
# [535]	train-merror:0.015387	validation-merror:0.462279
# [536]	train-merror:0.015387	validation-merror:0.461209
# [537]	train-merror:0.015253	validation-merror:0.461744
# [538]	train-merror:0.015253	validation-merror:0.462814
# [539]	train-merror:0.015119	validation-merror:0.462814
# [540]	train-merror:0.015119	validation-merror:0.461744
# [541]	train-merror:0.015119	validation-merror:0.461744
# [542]	train-merror:0.015119	validation-merror:0.461744
# [543]	train-merror:0.015119	validation-merror:0.462814
# [544]	train-merror:0.015119	validation-merror:0.462279
# [545]	train-merror:0.014851	validation-merror:0.462279
# [546]	train-merror:0.014718	validation-merror:0.461744
# [547]	train-merror:0.014718	validation-merror:0.462279
# [548]	train-merror:0.014718	validation-merror:0.461744
# [549]	train-merror:0.014718	validation-merror:0.461744
# [550]	train-merror:0.014584	validation-merror:0.462279
# [551]	train-merror:0.014718	validation-merror:0.462279
# [552]	train-merror:0.014584	validation-merror:0.462279
# [553]	train-merror:0.014316	validation-merror:0.462279
# [554]	train-merror:0.014316	validation-merror:0.462279
# [555]	train-merror:0.014584	validation-merror:0.462279
# [556]	train-merror:0.014049	validation-merror:0.462279
# [557]	train-merror:0.013915	validation-merror:0.462279
# [558]	train-merror:0.014049	validation-merror:0.462279
# [559]	train-merror:0.014182	validation-merror:0.461744
# [560]	train-merror:0.013915	validation-merror:0.461744
# [561]	train-merror:0.013781	validation-merror:0.461209
# [562]	train-merror:0.013647	validation-merror:0.461209
# [563]	train-merror:0.013647	validation-merror:0.461744
# [564]	train-merror:0.013647	validation-merror:0.461744
# [565]	train-merror:0.013647	validation-merror:0.462279
# [566]	train-merror:0.013647	validation-merror:0.462279
# [567]	train-merror:0.013647	validation-merror:0.461744
# [568]	train-merror:0.013647	validation-merror:0.461744
# [569]	train-merror:0.013380	validation-merror:0.461744
# [570]	train-merror:0.013514	validation-merror:0.462814
# [571]	train-merror:0.013514	validation-merror:0.462279
# [572]	train-merror:0.013514	validation-merror:0.462279
# [573]	train-merror:0.013380	validation-merror:0.463349
# [574]	train-merror:0.013380	validation-merror:0.462814
# [575]	train-merror:0.013380	validation-merror:0.463349
# [576]	train-merror:0.013246	validation-merror:0.463884
# [577]	train-merror:0.012978	validation-merror:0.463349
# [578]	train-merror:0.012978	validation-merror:0.463349
# [579]	train-merror:0.012711	validation-merror:0.463349
# [580]	train-merror:0.012577	validation-merror:0.463349
# [581]	train-merror:0.012577	validation-merror:0.463349
# [582]	train-merror:0.012577	validation-merror:0.463349
# [583]	train-merror:0.012577	validation-merror:0.462814
# [584]	train-merror:0.012577	validation-merror:0.462814
# [585]	train-merror:0.012577	validation-merror:0.462814
# [586]	train-merror:0.012443	validation-merror:0.462814
# [587]	train-merror:0.012443	validation-merror:0.463349
# [588]	train-merror:0.012443	validation-merror:0.462814
# [589]	train-merror:0.012309	validation-merror:0.462814
# [590]	train-merror:0.012309	validation-merror:0.462279
# [591]	train-merror:0.012309	validation-merror:0.462279
# [592]	train-merror:0.012309	validation-merror:0.462279
# [593]	train-merror:0.012176	validation-merror:0.462279
# [594]	train-merror:0.012176	validation-merror:0.462279
# [595]	train-merror:0.012176	validation-merror:0.461744
# [596]	train-merror:0.012176	validation-merror:0.461744
# [597]	train-merror:0.012042	validation-merror:0.461744
# [598]	train-merror:0.012042	validation-merror:0.461209
# [599]	train-merror:0.012042	validation-merror:0.461744
# [600]	train-merror:0.012042	validation-merror:0.461209
# [601]	train-merror:0.011908	validation-merror:0.461744
# [602]	train-merror:0.011774	validation-merror:0.461744
# [603]	train-merror:0.011774	validation-merror:0.461744
# [604]	train-merror:0.011774	validation-merror:0.461744
# [605]	train-merror:0.011774	validation-merror:0.461744
# [606]	train-merror:0.011774	validation-merror:0.461744
# [607]	train-merror:0.011640	validation-merror:0.462279
# [608]	train-merror:0.011640	validation-merror:0.462279
# [609]	train-merror:0.011507	validation-merror:0.462279
# [610]	train-merror:0.011507	validation-merror:0.462279
# [611]	train-merror:0.011373	validation-merror:0.462279
# [612]	train-merror:0.011239	validation-merror:0.462279
# [613]	train-merror:0.011239	validation-merror:0.462279
# [614]	train-merror:0.011105	validation-merror:0.462814
# [615]	train-merror:0.011105	validation-merror:0.462279
# [616]	train-merror:0.010971	validation-merror:0.462814
# [617]	train-merror:0.010971	validation-merror:0.462814
# [618]	train-merror:0.010971	validation-merror:0.462279
# [619]	train-merror:0.010971	validation-merror:0.462279
# [620]	train-merror:0.010971	validation-merror:0.462814
# [621]	train-merror:0.010971	validation-merror:0.462279
# [622]	train-merror:0.010838	validation-merror:0.462279
# [623]	train-merror:0.010570	validation-merror:0.462814
# [624]	train-merror:0.010570	validation-merror:0.462814
# [625]	train-merror:0.010570	validation-merror:0.462814
# [626]	train-merror:0.010302	validation-merror:0.462814
# [627]	train-merror:0.010302	validation-merror:0.462814
# [628]	train-merror:0.010035	validation-merror:0.462814
# [629]	train-merror:0.009901	validation-merror:0.462814
# [630]	train-merror:0.010035	validation-merror:0.463349
# [631]	train-merror:0.010035	validation-merror:0.462814
# [632]	train-merror:0.009901	validation-merror:0.462814
# [633]	train-merror:0.009901	validation-merror:0.462279
# [634]	train-merror:0.009901	validation-merror:0.462279
# [635]	train-merror:0.009901	validation-merror:0.462279
# [636]	train-merror:0.009901	validation-merror:0.462279
# [637]	train-merror:0.009901	validation-merror:0.461744
# [638]	train-merror:0.009901	validation-merror:0.461744
# [639]	train-merror:0.009767	validation-merror:0.461744
# [640]	train-merror:0.009901	validation-merror:0.461744
# [641]	train-merror:0.009767	validation-merror:0.461744
# [642]	train-merror:0.009633	validation-merror:0.461744
# [643]	train-merror:0.009500	validation-merror:0.461744
# [644]	train-merror:0.009500	validation-merror:0.461209
# [645]	train-merror:0.009500	validation-merror:0.461744
# [646]	train-merror:0.009500	validation-merror:0.461744
# [647]	train-merror:0.009500	validation-merror:0.461744
# [648]	train-merror:0.009500	validation-merror:0.461744
# [649]	train-merror:0.009366	validation-merror:0.461744
# [650]	train-merror:0.009366	validation-merror:0.461209
# [651]	train-merror:0.009366	validation-merror:0.461209
# [652]	train-merror:0.009366	validation-merror:0.461209
# [653]	train-merror:0.009366	validation-merror:0.461209
# [654]	train-merror:0.009366	validation-merror:0.461744
# [655]	train-merror:0.009366	validation-merror:0.461744
# [656]	train-merror:0.009366	validation-merror:0.460674
# [657]	train-merror:0.009366	validation-merror:0.461209
# [658]	train-merror:0.009366	validation-merror:0.461209
# [659]	train-merror:0.009366	validation-merror:0.460674

# %% [markdown]
# # Store xgboost model for future use

# %%
# save xgb model object so it can be reloaded and used to make predictions without training
bst_return_prob.save_model('/home/ec2-user/Kaggle/facebook_Jul_2016/models/k_posted.model') 

# dump model - weak classifiers built - in this case would be decision tree stumps 
bst_return_prob.dump_model('/home/ec2-user/Kaggle/facebook_Jul_2016/models/k_posted_raw.txt')

# %% [markdown]
# # Make predictions using xgboost model - takes a while

# %%
# prediction for testing set
preds_prob = bst_return_prob.predict(xg_test)
print preds_prob.shape
# Out:
# (2753, 660)

# %% [markdown]
# # Convert xgboost outputs (probability matrix) back to original place_id

# %%
sortedProbIdx = np.argsort(preds_prob)

top3prob = sortedProbIdx[:, -3:]

print top3prob
print top3prob.shape
# Out:
# [[ 60 180  24]
#  [ 21  52  43]
#  [469   3  21]
#  ...,
#  [ 37  81  17]
#  [250  22  17]
#  [147  10  23]]
# (2753, 3)

# %%
finalResults = unique_placeID[top3prob]
print finalResults.shape
print type(finalResults)

np.set_printoptions(precision=10)
print finalResults[0:3]

if 4789348989 in place_id:
    print True
# Out:
# (2753, 3)
# <type 'numpy.ndarray'>
# [[  4.7893489890e+09   8.7431971440e+09   9.1778043280e+09]
#  [  6.1334719400e+09   2.7398940110e+09   8.3790478080e+09]
#  [  4.5131063140e+09   2.4953751170e+09   6.1334719400e+09]]
# True
